# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/StringIndexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CreditCardNumber = "1234-5678-9012-3456"

#print(CreditCardNumber[0])
#print(CreditCardNumber[1])
#print(CreditCardNumber[2])

#print(CreditCardNumber[5:8])
#print(CreditCardNumber[:9])

#print(CreditCardNumber[-1])
#print(CreditCardNumber[-3])

#print(CreditCardNumber[-4:])
#print(CreditCardNumber[-9:-1])

print(CreditCardNumber[::2])
# Out:
# 13-6891-46
