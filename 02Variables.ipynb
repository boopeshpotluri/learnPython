# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/02Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Variables string, integer, float, boolean

#string
#fullName = input("Please enter your full name :")
#address = input("Please enter your address :")

#print(f"You are : {fullName}")
#print(f"You stay at : {address}")


#integer
#age = 30
#numberOfSiblings = 2

#print(f"Your age is : {age} and you have {numberOfSiblings} siblings")

#float
#gpa = 4.438
#q1TermGrade = 96.68

#print(f"Your previous year gpa is {gpa} and your Q1 Term Grade is {q1TermGrade}")

#boolean
stayWithParents = True
completedDriverEd = False

print(f"Do you stay with your parents : {stayWithParents}")
print(f"Have you completed your Driver Ed program : {completedDriverEd}")
# Out:
# Do you stay with your parents : True
# Have you completed your Driver Ed program : False
