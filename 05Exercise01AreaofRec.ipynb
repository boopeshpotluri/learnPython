# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/05Exercise01AreaofRec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calculate area of a rectangle

length = float(input("Enter the length of rectangle : "))
width = float(input("Enter the width of rectangle : "))

Area = length * width

print(f"Area of the reactangle is : {Area} cm²")
# Out:
# Enter the length of rectangle : 4.5
# Enter the width of rectangle : 3.5
# Area of the reactangle is : 15.75 cm²
