# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/07MathFunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Math functions

gasPrice = 4.27679
print(round(gasPrice))
print(round(gasPrice,2))

number = 4
print(pow(4, 3))

i = 90
x = 56.98
y = 32
z = 12.37

print(min(i, x, y, z))
print(max(i, x, y, z))
# Out:
# 4
# 4.28
# 64
# 12.37
# 90
