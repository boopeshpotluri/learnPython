# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/04TypeCast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Type Cast function str, int, float, bool

#Student Details

fullName = "John Doe"
currentAge = 16
previousYearGPA = 4.438
attendForeignLanguageClass = True


# find data type
print(type(fullName))
print(type(currentAge))
print(type(previousYearGPA))
print(type(attendForeignLanguageClass))


#type cast int to str, floar
#print(str(currentAge))
#print(float(currentAge))

#type cast float to str, int
print(str(previousYearGPA))
print(int(previousYearGPA))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 4.438
# 4
