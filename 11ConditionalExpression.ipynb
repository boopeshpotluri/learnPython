# %% [markdown]
# <a href="https://colab.research.google.com/github/boopeshpotluri/learnPython/blob/main/11ConditionalExpression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Conditional Expression    X if condition else Y

temp = 81

print("Its Very HOT !!!" if temp>80 else "It isn't that HOT!")
# Out:
# Its Very HOT !!!
